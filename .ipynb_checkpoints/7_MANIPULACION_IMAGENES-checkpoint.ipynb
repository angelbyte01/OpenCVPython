# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = cv2.imread('gato.jpg')
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen.shape
# Out:
# (960, 940, 3)

# %%
imagen_2=cv2.resize(imagen,(600,500))

# %%
plt.imshow(imagen_2)

# %%
ratio_ancho = 0.5
ratio_alto =0.5

# %%
imagen_2 = cv2.resize(imagen, (0,0), imagen, ratio_ancho, ratio_alto)

# %%
plt.imshow(imagen_2)

# %%
imagen_2.shape
# Out:
# (480, 470, 3)

# %%
imagen_2=cv2.flip(imagen_2,1)

# %%
plt.imshow(imagen_2)

# %%
imagen_2 = cv2.flip(imagen_2,0)

# %%
plt.imshow(imagen_2)

# %%
cv2.imwrite('gato_cabeza.jpg',imagen_2)
# Out:
# True
